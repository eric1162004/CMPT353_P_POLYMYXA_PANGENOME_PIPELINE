# %%
# Cell 1: Regenerate the clean binary matrix
import src.matrix_generator as mg

print("🧪 STEP 1: RE-RUNNING MATRIX GENERATION")
print("=" * 50)
updated_matrix = mg.run_matrix_generation()

# Confirm that we have multiple rows (strains) now
print(f"Matrix shape in memory: {updated_matrix.shape}")
# Out:
# 🧪 STEP 1: RE-RUNNING MATRIX GENERATION
# ==================================================
# Starting Data extraction from: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\data
# Found 4 strain assemblies to parse.
# - GCF_000146875.3: Extracted 2327 unique functional genes.
# - GCF_001719045.1: Extracted 2459 unique functional genes.
# - GCF_003956325.1: Extracted 4339 unique functional genes.
# - GCF_022811565.1: Extracted 2449 unique functional genes.
# Global Pangenome vector built. Total unique features: 6435
# Success! Binary Matrix saved directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
#
# Matrix shape in memory: (4, 6435)

# %%
# Cell 2: Re-run the pangenome statistics analyzer
from src.pangenome_statistics import run_pangenome_analytics

print("\n🧪 STEP 2: RE-RUNNING STATISTICS ANALYTICS")
print("=" * 50)
stats_results = run_pangenome_analytics()

if stats_results is not None:
    print("\n📊 UPDATED TABULAR STRATA PROFILE:")
    print("-" * 35)
    display(stats_results["summary_table"])
    
    print(f"\n✅ Updated Core Sample: {stats_results['core'][:3]}")
    print(f"✅ Updated Shell Sample: {stats_results['shell'][:3]}")
    print(f"✅ Updated Cloud Sample: {stats_results['cloud'][:3]}")
# Out:
# 🧪 STEP 2: RE-RUNNING STATISTICS ANALYTICS
# ==================================================
# Loading binary matrix from: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
# Analyzing 6435 total unique genes across 4 strains.
# Statistical profile saved directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\accessory_genome_heatmap.png
# Pie chart exported to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_pie_distribution.png
#
#
# 📊 UPDATED TABULAR STRATA PROFILE:
# -----------------------------------
#      genomic_layer  gene_count  percentage_of_total
# 0             Core         664             10.31857
# 1            Shell        5771             89.68143
# 2            Cloud           0              0.00000
# 3  Total_Pangenome        6435            100.00000
# ✅ Updated Core Sample: ['3_ketoacyl_acp_reductase', '6_phospho_beta_glucosidase', 'aaa_family_atpase']
# ✅ Updated Shell Sample: ['16s_rrna_uracil_1498_n_3_methyltransferase', '1_2c2_dihydroxy_3_keto_5_methylthiopentene_dioxygenase', '1_2c4_dihydroxy_6_naphthoate_synthase']
# ✅ Updated Cloud Sample: []

# %%
# Cell 5
from src.pca_analysis import run_pca_analysis

print("🧪 TESTING PCA ANALYSIS LAYER:")
print("=" * 50)

# Run PCA dimensionality reduction
pca_coords = run_pca_analysis()

if pca_coords is not None:
    print("\n📊 TRANSFORMD 2D PCA COORDINATES:")
    print("-" * 35)
    display(pca_coords)
# Out:
# 🧪 TESTING PCA ANALYSIS LAYER:
# ==================================================
# Loading matrix for PCA from: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
# PCA complete. PC1 explains 88.1%, PC2 explains 6.7%
# PCA cluster plot exported directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pca_clusters.png
#
#
# 📊 TRANSFORMD 2D PCA COORDINATES:
# -----------------------------------
#                        PC1        PC2
# GCF_000146875.3  17.271427  12.367852
# GCF_001719045.1  18.511463  -0.230060
# GCF_003956325.1 -53.942872  -0.153536
# GCF_022811565.1  18.159982 -11.984256

# %%
# Cell 6
from src.heatmap_analysis import run_heatmap_analysis

print("🧪 TESTING ACCESSORY HEATMAP LAYER:")
print("=" * 50)

# Run clustering pipeline
accessory_matrix = run_heatmap_analysis()

if accessory_matrix is not None:
    print("\n📊 ACCESSORY MATRIX SHAPE VERIFICATION:")
    print("-" * 35)
    print(f"Filtered DataFrame Dimensions: {accessory_matrix.shape} (Strains, Variable Genes)")
# Out:
# 🧪 TESTING ACCESSORY HEATMAP LAYER:
# ==================================================
# Loading matrix for Heatmap from: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
# Core filtered out. Plotting 5771 variable accessory gene.
# Computing stable hierarchical linkage trees...
# Hierarchical clustermap exported straight to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\accessory_genome_heatmap.png
#
#
# 📊 ACCESSORY MATRIX SHAPE VERIFICATION:
# -----------------------------------
# Filtered DataFrame Dimensions: (4, 5771) (Strains, Variable Genes)

# %%
# Cell 7
from src.tsne_analysis import run_tsne_analysis

print("🧪 TESTING T-SNE MANIFOLD LAYER:")
print("=" * 50)

# Run t-SNE dimensionality reduction
tsne_coords = run_tsne_analysis()

if tsne_coords is not None:
    print("\n📊 TRANSFORMED 2D T-SNE COORDINATES:")
    print("-" * 35)
    display(tsne_coords)
# Out:
# 🧪 TESTING T-SNE MANIFOLD LAYER:
# ==================================================
# Loading matrix for t-SNE from: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
# Calculating pairwise Jaccard distances...
# Fitting t-SNE embedding (Perplexity = 3)
# t-SNE cluster plot exported directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\tsne_clusters.png
#
#
# 📊 TRANSFORMED 2D T-SNE COORDINATES:
# -----------------------------------
#                    t-SNE 1    t-SNE 2
# GCF_000146875.3  40.690712 -99.189209
# GCF_001719045.1 -96.864304 -72.221588
# GCF_003956325.1 -70.727577  65.780121
# GCF_022811565.1  67.014214  38.492661

# %%
# Cell 8
from src.pangenome_autoencoder import train_autoencoder

print("🧪 TESTING DEEP LEARNING EMBEDDING ENGINE:")
print("=" * 50)

# Make sure you have customized config.EMBEDDING_CSV path inside your config module
latent_features = train_autoencoder()

if latent_features is not None:
    print("\n📊 EXTRACTED NON-LINEAR LATENT COORDINATES:")
    print("-" * 45)
    display(latent_features)
# Out:
# 🧪 TESTING DEEP LEARNING EMBEDDING ENGINE:
# ==================================================
# Initializing NN training pipeline using matrix: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pangenome_matrix.csv
# Small cohort detected. Switching architecture to stable training mode (disabling BatchNorm).
# training model across 200 epochs..
# Epoch   1/1 | Reconstruction Loss: 0.7171
# Epoch  40/40 | Reconstruction Loss: 0.0202
# Epoch  80/80 | Reconstruction Loss: 0.0005
# Epoch 120/120 | Reconstruction Loss: 0.0002
# Epoch 160/160 | Reconstruction Loss: 0.0004
# Epoch 200/200 | Reconstruction Loss: 0.0002
# Latent space coords exported directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\autoencoder_latent_coords.csv
#  Training loss plot saved to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\autoencoder_loss.png
#
#
# 📊 EXTRACTED NON-LINEAR LATENT COORDINATES:
# ---------------------------------------------
#                  Latent Dimension 1  Latent Dimension 2
# GCF_000146875.3            0.464066           -0.148871
# GCF_001719045.1            0.857354            0.138593
# GCF_003956325.1           -0.361782            0.057629
# GCF_022811565.1            0.433458            0.290067

# %%
# Cell 9
from src.biomarker_extractor import run_biomarker_extraction

print("🧪 TESTING BIOMARKER EXTRACTION MODULE:")
print("=" * 50)

# Run feature mining
pca_drivers, nn_drivers = run_biomarker_extraction()

if pca_drivers is not None:
    print("\n📊 MINED PCA LINEAR DRIVERS (TOP 5 SAMPLE):")
    print("-" * 45)
    display(pca_drivers.head(5))
    
    print("\n📊 MINED NEURAL NETWORK DRIVERS (TOP 5 SAMPLE):")
    print("-" * 45)
    display(nn_drivers.head(5))
# Out:
# 🧪 TESTING BIOMARKER EXTRACTION MODULE:
# ==================================================
# Initializing Biomarker Extractor Engine...
# Extracting linear driver genes via PCA loadings...
# Top PCA linear drivers saved directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pca_driver_genes.csv
# Mining non-linear drivers via latent space correlation profiling...
# Top Neural Network non-linear driver saved directly to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\nn_driver_genes.csv
#
#
# 📊 MINED PCA LINEAR DRIVERS (TOP 5 SAMPLE):
# ---------------------------------------------
#                                               Gene_Name  PC1_Loading  \
# 1     1_2c2_dihydroxy_3_keto_5_methylthiopentene_dio...     0.013901
# 6423                                               znta    -0.013901
# 6407                                               zapg    -0.013901
# 6433                                                zur    -0.013901
# 20           2fe_2s_iron_sulfur_cluster_binding_protein     0.013901
#
#       PC2_Loading  Absolute_PC1_Impact  Absolute_PC2_Impact
# 1        0.000518             0.013901             0.000518
# 6423    -0.000518             0.013901             0.000518
# 6407    -0.000518             0.013901             0.000518
# 6433    -0.000518             0.013901             0.000518
# 20       0.000518             0.013901             0.000518
# 📊 MINED NEURAL NETWORK DRIVERS (TOP 5 SAMPLE):
# ---------------------------------------------
#                                               Gene_Name  Latent_Dim1_Corr  \
# 5770                                                zur         -0.925981
# 0            16s_rrna_uracil_1498_n_3_methyltransferase          0.925981
# 1     1_2c2_dihydroxy_3_keto_5_methylthiopentene_dio...          0.925981
# 5769                                               zupt         -0.925981
# 5768                                               zras         -0.925981
#
#       Latent_Dim2_Corr  Max_Absolute_Correlation
# 5770         -0.097409                  0.925981
# 0             0.097409                  0.925981
# 1             0.097409                  0.925981
# 5769         -0.097409                  0.925981
# 5768         -0.097409                  0.925981

# %%
# Cell 10
from src.pathogenicity_predictor import run_pathogenicity_prediction

print("🧪 TESTING PATHOGENICITY PREDICTOR MANIFEST:")
print("=" * 50)

# Run prediction profiling
risk_profiles = run_pathogenicity_prediction()

if risk_profiles is not None:
    print("\n📊 STRATIFIED GENOMIC RISK PROFILES:")
    print("-" * 45)
    display(risk_profiles)
# Out:
# 🧪 TESTING PATHOGENICITY PREDICTOR MANIFEST:
# ==================================================
# Initializing Pathogenicity Predictor Engine..
# Scanning accessory genome for high-rish clinical and environmental factors...
# Identified 43 potnetial risk-associated features in global pool.
# Pathogenicity risk profile records exported to: c:\Users\eric1\OneDrive - Simon Fraser University (1sfu)\GraduateResearch\BioinformaticsResearch\Projects\P. polymyxa Project\Project\CMPT353_P_POLYMYXA_PANGENOME_PIPELINE\outputs\pathogenicity_risk_profile.csv
#
#
# 📊 STRATIFIED GENOMIC RISK PROFILES:
# ---------------------------------------------
#                  Risk_Associated_Gene_Count  Pathogenicity_Risk_Index
# GCF_022811565.1                          25                      1.00
# GCF_001719045.1                          23                      0.92
# GCF_000146875.3                          18                      0.72
# GCF_003956325.1                          18                      0.72
